# %% [markdown]
# ## Goal
# Pack 14 Christmas tree polygons into the smallest square. Target score: 0.3696
#
# Score formula: `max(width, height)^2 / N`

# %%
# !git clone https://github.com/SmartManoj/sparrow
# Out:
# Cloning into 'sparrow'...
# remote: Enumerating objects: 4699, done.
# remote: Counting objects: 100% (617/617), done.
# remote: Compressing objects: 100% (309/309), done.
# remote: Total 4699 (delta 388), reused 326 (delta 306), pack-reused 4082 (from 3)
# Receiving objects: 100% (4699/4699), 11.00 MiB | 28.30 MiB/s, done.
# Resolving deltas: 100% (3293/3293), done.

# %%
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
# Out:
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# info: syncing channel updates for 'stable-x86_64-unknown-linux-gnu'
# info: latest update on 2025-12-11, rust version 1.92.0 (ded5c06cf 2025-12-08)
# info: downloading component 'cargo'
# info: downloading component 'clippy'
# info: downloading component 'rust-docs'
# info: downloading component 'rust-std'
# info: downloading component 'rustc'
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
#  10.3 MiB /  10.3 MiB (100 %)   9.4 MiB/s in  1s
# info: installing component 'clippy'
# info: installing component 'rust-docs'
#  20.5 MiB /  20.5 MiB (100 %)   5.1 MiB/s in  3s
# info: installing component 'rust-std'
#  28.0 MiB /  28.0 MiB (100 %)   8.7 MiB/s in  3s
# info: installing component 'rustc'
#  74.3 MiB /  74.3 MiB (100 %)   9.3 MiB/s in  8s
# info: installing component 'rustfmt'
# info: default toolchain set to 'stable-x86_64-unknown-linux-gnu'
#
#   stable-x86_64-unknown-linux-gnu installed - rustc 1.92.0 (ded5c06cf 2025-12-08)
#
#
# Rust is installed now. Great!
#
# To get started you may need to restart your current shell.
# This would reload your PATH environment variable to include
# Cargo's bin directory ($HOME/.cargo/bin).
#
# To configure your current shell, you need to source
# the corresponding env file under $HOME/.cargo.
#
# This is usually done by running one of the following (note the leading DOT):
# . "$HOME/.cargo/env"            # For sh/bash/zsh/ash/dash/pdksh
# source "$HOME/.cargo/env.fish"  # For fish
# source $"($nu.home-path)/.cargo/env.nu"  # For nushell

# %%
 # !rustup default nightly
# Out:
# info: syncing channel updates for 'nightly-x86_64-unknown-linux-gnu'
# info: latest update on 2026-01-17, rust version 1.94.0-nightly (f6a07efc8 2026-01-16)
# info: downloading component 'cargo'
# info: downloading component 'clippy'
# info: downloading component 'rust-docs'
# info: downloading component 'rust-std'
# info: downloading component 'rustc'
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
#  10.4 MiB /  10.4 MiB (100 %)   9.5 MiB/s in  1s
# info: installing component 'clippy'
# info: installing component 'rust-docs'
#  20.6 MiB /  20.6 MiB (100 %)   4.7 MiB/s in  3s
# info: installing component 'rust-std'
#  28.3 MiB /  28.3 MiB (100 %)   8.8 MiB/s in  3s
# info: installing component 'rustc'
#  74.8 MiB /  74.8 MiB (100 %)   9.3 MiB/s in  8s
# info: installing component 'rustfmt'
# info: default toolchain set to 'nightly-x86_64-unknown-linux-gnu'
#
#   nightly-x86_64-unknown-linux-gnu installed - rustc 1.94.0-nightly (f6a07efc8 2026-01-16)

# %%
import os
os.environ['PATH']+=':/root/.cargo/bin'

# %% [markdown]
# ### 1. Create input file

# %%
data = '''
{
  "name": "n14_h2280",
  "items": [{
    "id": 0,
    "demand": 14,
    "shape": {
      "type": "simple_polygon",
      "data": [[0,800],[125,500],[62.5,500],[200,250],[100,250],[350,0],[75,0],[75,-200],[-75,-200],[-75,0],[-350,0],[-100,250],[-200,250],[-62.5,500],[-125,500]]
    }
  }],
  "strip_height": 2280
}
'''
with open('n14_h2280.json','w') as f: f.write(data)

# %% [markdown]
# ## Why Height 2280?
#
# `2280` = strip height for sparrow (scaled by 1000)
#
# **In real coordinates:**
# - 2280 / 1000 = **2.280** (the height constraint)
#
# **Target calculation:**
# - Target score 0.3696 means: `side² / 14 = 0.3696`
# - So target side = `sqrt(0.3696 × 14)` = **2.2747**
# - Scaled: 2274.7
#
# We use 2280 (slightly above 2275) to give sparrow room to optimize. Sparrow minimizes width for a fixed height - if height is too tight, width explodes.
#
# **Trade-off found empirically:**
#
# | Height | Best Width | max(w,h) | Score |
# |--------|------------|----------|-------|
# | 2275   | 2344       | 2344     | 0.392 |
# | 2280   | 2280       | 2280     | 0.371 |
# | 2300   | 2333       | 2333     | 0.389 |
#
# Height **2280** gives the best balance where width ≈ height ≈ 2280.

# %% [markdown]
# ### 2. Run sparrow
#
# Parameters:
# - `-t 600`: 600 seconds optimization time
# - `-s 42`: random seed (try different seeds: 42, 100, 200, etc.)
# - Strip height 2280 found to be optimal for N=14

# %%
# !cd sparrow && cargo run --release --features=simd,only_final_svg -- -i ../n14_h2280.json -t 600 -s 42
# Out:
#    Compiling autocfg v1.5.0
#    Compiling libm v0.2.15             ] 0/130: autocfg
#    Compiling libc v0.2.180
#    Compiling proc-macro2 v1.0.105
#    Compiling unicode-ident v1.0.22    ] 3/130: autocfg, libc(build.rs), li…
#    Compiling quote v1.0.43            ] 5/130: unicode-ident, autocfg, lib…
#    Compiling num-traits v0.2.19       ] 7/130: proc-macro2, quote(build.rs…
#    Compiling cfg-if v1.0.4           ] 11/130: proc-macro2, libc, libm, nu…
#    Compiling semver v1.0.27          ] 12/130: proc-macro2, cfg-if, libc, …
#    Compiling syn v2.0.114            ] 14/130: quote, proc-macro2, libc, l…
#    Compiling rustc_version v0.4.1    ] 15/130: quote, syn, libc, libm
#    Compiling getrandom v0.3.4        ] 16/130: syn, rustc_version, libc, l…
#    Compiling scopeguard v1.2.0       ] 18/130: num-traits, syn, libc, libm
#    Compiling lock_api v0.4.14        ] 19/130: num-traits, syn, scopeguard…
#    Compiling heapless v0.7.17        ] 21/130: num-traits, syn, libc, getr…
#    Compiling crossbeam-utils v0.8.21 ] 22/130: num-traits, syn, libc, heap…
#    Compiling byteorder v1.5.0        ] 23/130: num-traits, syn, crossbeam-…
#    Compiling zerocopy v0.8.33        ] 24/130: num-traits, syn, crossbeam-…
#    Compiling hash32 v0.2.1           ] 25/130: num-traits, syn, zerocopy(b…
#    Compiling spin v0.9.8             ] 30/130: getrandom, heapless(build),…
#    Compiling stable_deref_trait v1.2.1 31/130: getrandom, spin, syn, hash32
#    Compiling rand_core v0.9.5        ] 32/130: getrandom, spin, syn, stabl…
#    Compiling serde_core v1.0.228     ] 36/130: syn, zerocopy, heapless, cr…
#    Compiling smallvec v1.15.1        ] 37/130: syn, zerocopy, serde_core(b…
#    Compiling crossbeam-epoch v0.9.18 ] 39/130: serde_core(build), smallvec…
# m    Building [=======>                  ] 40/130: smallvec, syn, zerocopy, cr…   Compiling rstar v0.10.0
#    Compiling approx v0.5.1           ] 41/130: syn, zerocopy, crossbeam-ep…
#    Compiling matrixmultiply v0.3.10  ] 42/130: syn, zerocopy, approx, rstar
#    Compiling utf8parse v0.2.2        ] 43/130: syn, zerocopy, rstar, matri…
#    Compiling rayon-core v1.13.0      ] 44/130: utf8parse, syn, zerocopy, m…
#    Compiling log v0.4.29             ] 45/130: utf8parse, syn, zerocopy, r…
#    Compiling cfg_aliases v0.2.1      ] 46/130: syn, zerocopy, rayon-core(b…
#    Compiling version_check v0.9.5    ] 47/130: syn, zerocopy, cfg_aliases,…
#    Compiling nix v0.30.1             ] 48/130: syn, zerocopy, version_chec…
#    Compiling slotmap v1.1.1          ] 49/130: syn, zerocopy, version_chec…
#    Compiling anstyle-parse v0.2.7    ] 51/130: syn, zerocopy, nix(build.rs…
#    Compiling geo-types v0.7.18       ] 53/130: anstyle-parse, matrixmultip…
#    Compiling ppv-lite86 v0.2.21      ] 54/130: anstyle-parse, syn, zerocop…
#    Compiling crossbeam-deque v0.8.6  ] 55/130: anstyle-parse, syn, ppv-lit…
#    Compiling rand_chacha v0.9.0      ] 57/130: syn, ppv-lite86, serde_core…
#    Compiling geographiclib-rs v0.2.5 ] 58/130: syn, rand_chacha, serde_cor…
#    Compiling colorchoice v1.0.4      ] 59/130: syn, rand_chacha, serde_cor…
#    Compiling serde v1.0.228          ] 60/130: colorchoice, syn, serde_cor…
#    Compiling anyhow v1.0.100         ] 62/130: serde(build.rs), syn, cfg-i…
#    Compiling either v1.15.0          ] 63/130: serde(build.rs), syn, anyho…
#    Compiling float_next_after v1.0.0 ] 64/130: syn, anyhow(build.rs), eith…
#    Compiling zmij v1.0.14            ] 65/130: syn, either, float_next_aft…
#    Compiling anstyle-query v1.1.5    ] 66/130: syn, either, serde_core, zm…
#    Compiling is_terminal_polyfill v1.70.2/130: anstyle-query, syn, serde_c…
#    Compiling rawpointer v0.2.1       ] 68/130: anstyle-query, syn, serde_c…
#    Compiling anstyle v1.0.13         ] 69/130: rawpointer, syn, serde_core…
#    Compiling robust v0.2.3           ] 70/130: rawpointer, anstyle, syn, s…
#    Compiling anstream v0.6.21        ] 71/130: anstyle, syn, serde_core, r…
#    Compiling serde_derive v1.0.228   ] 72/130: anstream, syn, serde_core, …
#    Compiling geo v0.24.1>            ] 73/130: anstream, serde_derive, ser…
#    Compiling test-case-core v3.3.1   ] 78/130: matrixmultiply, serde_deriv…
#    Compiling rand v0.9.2=>           ] 79/130: matrixmultiply, serde_deriv…
#    Compiling num-complex v0.4.6      ] 83/130: rayon-core, serde_derive, g…
#    Compiling num-integer v0.1.46     ] 84/130: rayon-core, serde_derive, n…
#    Compiling clap_lex v0.7.7         ] 85/130: rayon-core, serde_derive, n…
#    Compiling heck v0.5.0===>         ] 86/130: rayon-core, num-complex, nu…
#    Compiling itoa v1.0.17==>         ] 87/130: rayon-core, num-integer, cl…
#    Compiling strsim v0.11.1>         ] 88/130: rayon-core, itoa, num-integ…
#    Compiling serde_json v1.0.149     ] 89/130: rayon-core, itoa, heck, str…
#    Compiling litrs v1.0.0===>        ] 90/130: rayon-core, itoa, serde_jso…
#    Compiling bitflags v2.10.0        ] 91/130: rayon-core, serde_json(buil…
#    Compiling clap_builder v4.5.54    ] 93/130: bitflags, litrs, serde_json…
#    Compiling clap_derive v4.5.49     ] 95/130: clap_builder, litrs, nix, s…
#    Compiling document-features v0.2.12 96/130: clap_builder, clap_derive, …
#    Compiling ndarray v0.17.2=>       ] 97/130: clap_builder, clap_derive, …
#    Compiling rayon v1.11.0===>       ] 99/130: clap_builder, clap_derive, …
#    Compiling geo-buffer v0.2.0      ] 101/130: rayon, clap_builder, slotma…
#    Compiling rand_distr v0.5.1      ] 102/130: rayon, clap_builder, geo-bu…
#    Compiling test-case-macros v3.3.1] 103/130: clap_builder, geo-buffer, r…
#    Compiling itertools v0.14.0>     ] 106/130: clap_builder, zmij, anyhow,…
#    Compiling float-cmp v0.10.0>     ] 107/130: clap_builder, zmij, itertoo…
#    Compiling ordered-float v5.1.0   ] 108/130: float-cmp, clap_builder, it…
#    Compiling svg v0.18.0======>     ] 109/130: ordered-float, clap_builder…
#    Compiling dtoa v1.0.11======>    ] 110/130: clap_builder, svg, itertool…
#    Compiling web-time v1.1.0===>    ] 111/130: dtoa, svg, itertools, ndarr…
#    Compiling memchr v2.7.6=====>    ] 112/130: svg, web-time, itertools, n…
#    Compiling numfmt v1.2.0=====>    ] 113/130: memchr, svg, itertools, nda…
#    Compiling jagua-rs v0.6.4 (https://github.com/JeroenGar/jagua-rs.git?rev=76aab0fa70688ee50d1809f5376f71c758ea0b7c#76aab0fa)
#    Compiling test-case v3.3.1===>   ] 116/130: memchr, jagua-rs, serde_jso…
#    Compiling clap v4.5.54=======>   ] 117/130: memchr, jagua-rs, test-case…
#    Compiling ctrlc v3.5.1=======>   ] 118/130: memchr, jagua-rs, clap, ser…
#    Compiling fern v0.7.1========>   ] 119/130: jagua-rs, clap, serde_json,…
#    Compiling rand_xoshiro v0.7.0=>  ] 120/130: jagua-rs, serde_json, ctrlc…
#    Compiling num_cpus v1.17.0====>  ] 121/130: jagua-rs, serde_json, rand_…
#    Compiling tap v1.0.1==========>  ] 122/130: num_cpus, jagua-rs, serde_j…
#    Compiling jiff v0.2.18========>  ] 123/130: num_cpus, jagua-rs, serde_j…
#    Compiling sparrow v0.1.0 (/kaggle/working/sparrow)
#     Finished `release` profile [optimized] target(s) in 1m 10s
#      Running `target/release/sparrow -i ../n14_h2280.json -t 600 -s 42`
# [INFO] [00:00:00] <main> [EPOCH]: 2026-01-17T10:03:29.780133041Z
# [INFO] [00:00:00] <main> [MAIN] configured to explore for 480s and compress for 120s
# [INFO] [00:00:00] <main> [MAIN] using seed: 42
# [INFO] [00:00:00] <main> [MAIN] system time: 2026-01-17T10:03:29.780689563Z
# [INFO] [00:00:00] <main> [PS] no simplification possible within area change constraints
# [INFO] [00:00:00] <main> [PS] no simplification possible within area change constraints
# [INFO] [00:00:00] <main> [MAIN] loaded instance n14_h2280 with #14 items
# [INFO] [00:00:00] <main> [EXPL] starting optimization with initial width: 3185.008 (47.354%)
# [INFO] [00:00:00] <main> [SEP] separating at width: 3185.008 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 4.2s
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3185.008 -> 3181.823
# [INFO] [00:00:00] <main> [SEP] separating at width: 3181.823 and loss: 100 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 510 K, evals/move: 221, moves/s: 2.30 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3181.823, dens: 47.401%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3181.823 -> 3178.641
# [INFO] [00:00:00] <main> [SEP] separating at width: 3178.641 and loss: 54.8 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 488 K, evals/move: 255, moves/s: 1.91 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3178.641, dens: 47.449%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3178.641 -> 3175.462
# [INFO] [00:00:00] <main> [SEP] separating at width: 3175.462 and loss: 105 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 547 K, evals/move: 260, moves/s: 2.09 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3175.462, dens: 47.496%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3175.462 -> 3172.287
# [INFO] [00:00:00] <main> [SEP] separating at width: 3172.287 and loss: 49.5 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 497 K, evals/move: 251, moves/s: 1.97 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3172.287, dens: 47.544%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3172.287 -> 3169.114
# [INFO] [00:00:00] <main> [SEP] separating at width: 3169.114 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.8s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3169.114, dens: 47.591%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3169.114 -> 3165.945
# [INFO] [00:00:00] <main> [SEP] separating at width: 3165.945 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.6s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3165.945, dens: 47.639%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3165.945 -> 3162.779
# [INFO] [00:00:00] <main> [SEP] separating at width: 3162.779 and loss: 50.1 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 371 K, evals/move: 225, moves/s: 1.64 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3162.779, dens: 47.687%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3162.779 -> 3159.616
# [INFO] [00:00:00] <main> [SEP] separating at width: 3159.616 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.6s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3159.616, dens: 47.734%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3159.616 -> 3156.457
# [INFO] [00:00:00] <main> [SEP] separating at width: 3156.457 and loss: 49.9 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 454 K, evals/move: 216, moves/s: 2.10 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3156.457, dens: 47.782%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3156.457 -> 3153.300
# [INFO] [00:00:00] <main> [SEP] separating at width: 3153.300 and loss: 48.1 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 353 K, evals/move: 234, moves/s: 1.50 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3153.300, dens: 47.830%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3153.300 -> 3150.147
# [INFO] [00:00:00] <main> [SEP] separating at width: 3150.147 and loss: 48.3 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 437 K, evals/move: 260, moves/s: 1.67 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3150.147, dens: 47.878%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3150.147 -> 3146.997
# [INFO] [00:00:00] <main> [SEP] separating at width: 3146.997 and loss: 48.2 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 383 K, evals/move: 228, moves/s: 1.68 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3146.997, dens: 47.926%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3146.997 -> 3143.850
# [INFO] [00:00:00] <main> [SEP] separating at width: 3143.850 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.1s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3143.850, dens: 47.974%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3143.850 -> 3140.706
# [INFO] [00:00:00] <main> [SEP] separating at width: 3140.706 and loss: 48.9 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 514 K, evals/move: 246, moves/s: 2.08 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3140.706, dens: 48.022%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3140.706 -> 3137.565
# [INFO] [00:00:00] <main> [SEP] separating at width: 3137.565 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 4.5s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3137.565, dens: 48.070%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3137.565 -> 3134.428
# [INFO] [00:00:00] <main> [SEP] separating at width: 3134.428 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.5s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3134.428, dens: 48.118%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3134.428 -> 3131.293
# [INFO] [00:00:00] <main> [SEP] separating at width: 3131.293 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.3s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3131.293, dens: 48.166%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3131.293 -> 3128.162
# [INFO] [00:00:00] <main> [SEP] separating at width: 3128.162 and loss: 101 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 460 K, evals/move: 226, moves/s: 2.03 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3128.162, dens: 48.214%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3128.162 -> 3125.034
# [INFO] [00:00:00] <main> [SEP] separating at width: 3125.034 and loss: 104 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 457 K, evals/move: 270, moves/s: 1.69 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3125.034, dens: 48.263%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3125.034 -> 3121.909
# [INFO] [00:00:00] <main> [SEP] separating at width: 3121.909 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 4.8s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3121.909, dens: 48.311%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3121.909 -> 3118.787
# [INFO] [00:00:00] <main> [SEP] separating at width: 3118.787 and loss: 57.1 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 442 K, evals/move: 240, moves/s: 1.84 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3118.787, dens: 48.359%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3118.787 -> 3115.668
# [INFO] [00:00:00] <main> [SEP] separating at width: 3115.668 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.1s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3115.668, dens: 48.408%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3115.668 -> 3112.553
# [INFO] [00:00:00] <main> [SEP] separating at width: 3112.553 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.5s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3112.553, dens: 48.456%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3112.553 -> 3109.440
# [INFO] [00:00:00] <main> [SEP] separating at width: 3109.440 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.6s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3109.440, dens: 48.505%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3109.440 -> 3106.331
# [INFO] [00:00:00] <main> [SEP] separating at width: 3106.331 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.9s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3106.331, dens: 48.553%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3106.331 -> 3103.225
# [INFO] [00:00:00] <main> [SEP] separating at width: 3103.225 and loss: 46.8 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 410 K, evals/move: 210, moves/s: 1.95 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3103.225, dens: 48.602%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3103.225 -> 3100.121
# [INFO] [00:00:00] <main> [SEP] separating at width: 3100.121 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.8s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3100.121, dens: 48.650%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3100.121 -> 3097.021
# [INFO] [00:00:00] <main> [SEP] separating at width: 3097.021 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3097.021, dens: 48.699%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3097.021 -> 3093.924
# [INFO] [00:00:00] <main> [SEP] separating at width: 3093.924 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.3s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3093.924, dens: 48.748%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3093.924 -> 3090.830
# [INFO] [00:00:00] <main> [SEP] separating at width: 3090.830 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.8s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3090.830, dens: 48.797%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3090.830 -> 3087.740
# [INFO] [00:00:00] <main> [SEP] separating at width: 3087.740 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.9s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3087.740, dens: 48.846%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3087.740 -> 3084.652
# [INFO] [00:00:00] <main> [SEP] separating at width: 3084.652 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.2s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3084.652, dens: 48.894%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3084.652 -> 3081.567
# [INFO] [00:00:00] <main> [SEP] separating at width: 3081.567 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3081.567, dens: 48.943%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3081.567 -> 3078.486
# [INFO] [00:00:00] <main> [SEP] separating at width: 3078.486 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.9s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3078.486, dens: 48.992%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3078.486 -> 3075.407
# [INFO] [00:00:00] <main> [SEP] separating at width: 3075.407 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.8s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3075.407, dens: 49.041%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3075.407 -> 3072.332
# [INFO] [00:00:00] <main> [SEP] separating at width: 3072.332 and loss: 55.5 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 422 K, evals/move: 255, moves/s: 1.65 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3072.332, dens: 49.091%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3072.332 -> 3069.260
# [INFO] [00:00:00] <main> [SEP] separating at width: 3069.260 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.9s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3069.260, dens: 49.140%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3069.260 -> 3066.190
# [INFO] [00:00:00] <main> [SEP] separating at width: 3066.190 and loss: 55.6 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 491 K, evals/move: 254, moves/s: 1.93 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3066.190, dens: 49.189%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3066.190 -> 3063.124
# [INFO] [00:00:00] <main> [SEP] separating at width: 3063.124 and loss: 55.8 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 432 K, evals/move: 221, moves/s: 1.95 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3063.124, dens: 49.238%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3063.124 -> 3060.061
# [INFO] [00:00:00] <main> [SEP] separating at width: 3060.061 and loss: 56.2 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 493 K, evals/move: 262, moves/s: 1.87 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3060.061, dens: 49.287%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3060.061 -> 3057.001
# [INFO] [00:00:00] <main> [SEP] separating at width: 3057.001 and loss: 56.9 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (*) min_l: 50.2 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:1] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 462 K, evals/move: 293, moves/s: 1.57 K, iter/s: 262, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3057.001, dens: 49.337%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3057.001 -> 3053.944
# [INFO] [00:00:00] <main> [SEP] separating at width: 3053.944 and loss: 104 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 624 K, evals/move: 248, moves/s: 2.50 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3053.944, dens: 49.386%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3053.944 -> 3050.890
# [INFO] [00:00:00] <main> [SEP] separating at width: 3050.890 and loss: 55.1 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 492 K, evals/move: 248, moves/s: 1.97 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3050.890, dens: 49.436%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3050.890 -> 3047.839
# [INFO] [00:00:00] <main> [SEP] separating at width: 3047.839 and loss: 55.6 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 417 K, evals/move: 230, moves/s: 1.81 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3047.839, dens: 49.485%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3047.839 -> 3044.792
# [INFO] [00:00:00] <main> [SEP] separating at width: 3044.792 and loss: 103 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 467 K, evals/move: 236, moves/s: 1.98 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3044.792, dens: 49.535%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3044.792 -> 3041.747
# [INFO] [00:00:00] <main> [SEP] separating at width: 3041.747 and loss: 47.7 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 423 K, evals/move: 242, moves/s: 1.74 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3041.747, dens: 49.584%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3041.747 -> 3038.705
# [INFO] [00:00:00] <main> [SEP] separating at width: 3038.705 and loss: 55.7 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 495 K, evals/move: 241, moves/s: 2.05 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3038.705, dens: 49.634%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3038.705 -> 3035.667
# [INFO] [00:00:00] <main> [SEP] separating at width: 3035.667 and loss: 55.9 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 541 K, evals/move: 286, moves/s: 1.89 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3035.667, dens: 49.683%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3035.667 -> 3032.631
# [INFO] [00:00:00] <main> [SEP] separating at width: 3032.631 and loss: 56.1 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 479 K, evals/move: 268, moves/s: 1.78 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3032.631, dens: 49.733%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3032.631 -> 3029.598
# [INFO] [00:00:00] <main> [SEP] separating at width: 3029.598 and loss: 100 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 482 K, evals/move: 248, moves/s: 1.94 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3029.598, dens: 49.783%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3029.598 -> 3026.569
# [INFO] [00:00:00] <main> [SEP] separating at width: 3026.569 and loss: 103 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (*) min_l: 49.5 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:3] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 513 K, evals/move: 250, moves/s: 2.04 K, iter/s: 323, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3026.569, dens: 49.833%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3026.569 -> 3023.542
# [INFO] [00:00:00] <main> [SEP] separating at width: 3023.542 and loss: 102 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (*) min_l: 50.6 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:1] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 500 K, evals/move: 266, moves/s: 1.88 K, iter/s: 209, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3023.542, dens: 49.883%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3023.542 -> 3020.519
# [INFO] [00:00:00] <main> [SEP] separating at width: 3020.519 and loss: 102 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 518 K, evals/move: 237, moves/s: 2.18 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3020.519, dens: 49.933%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3020.519 -> 3017.498
# [INFO] [00:00:00] <main> [SEP] separating at width: 3017.498 and loss: 45.6 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 461 K, evals/move: 222, moves/s: 2.07 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3017.498, dens: 49.983%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3017.498 -> 3014.481
# [INFO] [00:00:00] <main> [SEP] separating at width: 3014.481 and loss: 102 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 503 K, evals/move: 243, moves/s: 2.07 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3014.481, dens: 50.033%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3014.481 -> 3011.466
# [INFO] [00:00:00] <main> [SEP] separating at width: 3011.466 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.1s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3011.466, dens: 50.083%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3011.466 -> 3008.455
# [INFO] [00:00:00] <main> [SEP] separating at width: 3008.455 and loss: 45.6 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 562 K, evals/move: 215, moves/s: 2.61 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3008.455, dens: 50.133%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3008.455 -> 3005.447
# [INFO] [00:00:00] <main> [SEP] separating at width: 3005.447 and loss: 56.8 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 427 K, evals/move: 226, moves/s: 1.88 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3005.447, dens: 50.183%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3005.447 -> 3002.441
# [INFO] [00:00:00] <main> [SEP] separating at width: 3002.441 and loss: 56.9 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 481 K, evals/move: 280, moves/s: 1.71 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 3002.441, dens: 50.233%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 3002.441 -> 2999.439
# [INFO] [00:00:00] <main> [SEP] separating at width: 2999.439 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.9s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2999.439, dens: 50.284%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2999.439 -> 2996.439
# [INFO] [00:00:00] <main> [SEP] separating at width: 2996.439 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.5s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2996.439, dens: 50.334%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2996.439 -> 2993.443
# [INFO] [00:00:00] <main> [SEP] separating at width: 2993.443 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2993.443, dens: 50.384%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2993.443 -> 2990.449
# [INFO] [00:00:00] <main> [SEP] separating at width: 2990.449 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.3s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2990.449, dens: 50.435%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2990.449 -> 2987.459
# [INFO] [00:00:00] <main> [SEP] separating at width: 2987.459 and loss: 56.8 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 486 K, evals/move: 242, moves/s: 2.00 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2987.459, dens: 50.485%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2987.459 -> 2984.472
# [INFO] [00:00:00] <main> [SEP] separating at width: 2984.472 and loss: 56.9 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 464 K, evals/move: 233, moves/s: 1.98 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2984.472, dens: 50.536%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2984.472 -> 2981.487
# [INFO] [00:00:00] <main> [SEP] separating at width: 2981.487 and loss: 44.6 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 367 K, evals/move: 212, moves/s: 1.72 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2981.487, dens: 50.586%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2981.487 -> 2978.506
# [INFO] [00:00:00] <main> [SEP] separating at width: 2978.506 and loss: 100 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 571 K, evals/move: 242, moves/s: 2.35 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2978.506, dens: 50.637%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2978.506 -> 2975.527
# [INFO] [00:00:00] <main> [SEP] separating at width: 2975.527 and loss: 55.2 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 392 K, evals/move: 251, moves/s: 1.56 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2975.527, dens: 50.688%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2975.527 -> 2972.552
# [INFO] [00:00:00] <main> [SEP] separating at width: 2972.552 and loss: 55.5 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 446 K, evals/move: 252, moves/s: 1.77 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2972.552, dens: 50.738%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2972.552 -> 2969.579
# [INFO] [00:00:00] <main> [SEP] separating at width: 2969.579 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.4s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2969.579, dens: 50.789%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2969.579 -> 2966.610
# [INFO] [00:00:00] <main> [SEP] separating at width: 2966.610 and loss: 102 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 454 K, evals/move: 245, moves/s: 1.85 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2966.610, dens: 50.840%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2966.610 -> 2963.643
# [INFO] [00:00:00] <main> [SEP] separating at width: 2963.643 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.1s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2963.643, dens: 50.891%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2963.643 -> 2960.680
# [INFO] [00:00:00] <main> [SEP] separating at width: 2960.680 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 3.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2960.680, dens: 50.942%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2960.680 -> 2957.719
# [INFO] [00:00:00] <main> [SEP] separating at width: 2957.719 and loss: 105 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 476 K, evals/move: 243, moves/s: 1.95 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2957.719, dens: 50.993%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2957.719 -> 2954.761
# [INFO] [00:00:00] <main> [SEP] separating at width: 2954.761 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 4.9s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2954.761, dens: 51.044%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2954.761 -> 2951.806
# [INFO] [00:00:00] <main> [SEP] separating at width: 2951.806 and loss: 53.8 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 437 K, evals/move: 225, moves/s: 1.93 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2951.806, dens: 51.095%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2951.806 -> 2948.855
# [INFO] [00:00:00] <main> [SEP] separating at width: 2948.855 and loss: 54.0 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 487 K, evals/move: 259, moves/s: 1.87 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2948.855, dens: 51.146%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2948.855 -> 2945.906
# [INFO] [00:00:00] <main> [SEP] separating at width: 2945.906 and loss: 102 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 511 K, evals/move: 246, moves/s: 2.07 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2945.906, dens: 51.197%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2945.906 -> 2942.960
# [INFO] [00:00:00] <main> [SEP] separating at width: 2942.960 and loss: 54.2 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 561 K, evals/move: 265, moves/s: 2.11 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2942.960, dens: 51.249%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2942.960 -> 2940.017
# [INFO] [00:00:00] <main> [SEP] separating at width: 2940.017 and loss: 48.2 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 387 K, evals/move: 238, moves/s: 1.62 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2940.017, dens: 51.300%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2940.017 -> 2937.077
# [INFO] [00:00:00] <main> [SEP] separating at width: 2937.077 and loss: 0
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 0 K, evals/move: NaN, moves/s: 0, iter/s: 0, #workers: 3, total 2.6s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2937.077, dens: 51.351%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2937.077 -> 2934.140
# [INFO] [00:00:00] <main> [SEP] separating at width: 2934.140 and loss: 48.5 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 466 K, evals/move: 239, moves/s: 1.94 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2934.140, dens: 51.403%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2934.140 -> 2931.206
# [INFO] [00:00:00] <main> [SEP] separating at width: 2931.206 and loss: 54.8 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 554 K, evals/move: 253, moves/s: 2.19 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2931.206, dens: 51.454%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2931.206 -> 2928.275
# [INFO] [00:00:00] <main> [SEP] separating at width: 2928.275 and loss: 55.8 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 439 K, evals/move: 260, moves/s: 1.68 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2928.275, dens: 51.506%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2928.275 -> 2925.347
# [INFO] [00:00:00] <main> [SEP] separating at width: 2925.347 and loss: 105 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 515 K, evals/move: 248, moves/s: 2.07 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2925.347, dens: 51.557%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2925.347 -> 2922.422
# [INFO] [00:00:00] <main> [SEP] separating at width: 2922.422 and loss: 104 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 477 K, evals/move: 236, moves/s: 2.01 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2922.422, dens: 51.609%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2922.422 -> 2919.499
# [INFO] [00:00:00] <main> [SEP] separating at width: 2919.499 and loss: 106 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 525 K, evals/move: 239, moves/s: 2.19 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2919.499, dens: 51.660%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2919.499 -> 2916.580
# [INFO] [00:00:00] <main> [SEP] separating at width: 2916.580 and loss: 57.4 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 494 K, evals/move: 246, moves/s: 2.00 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2916.580, dens: 51.712%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2916.580 -> 2913.663
# [INFO] [00:00:00] <main> [SEP] separating at width: 2913.663 and loss: 105 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 472 K, evals/move: 240, moves/s: 1.96 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2913.663, dens: 51.764%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2913.663 -> 2910.750
# [INFO] [00:00:00] <main> [SEP] separating at width: 2910.750 and loss: 58.6 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 554 K, evals/move: 234, moves/s: 2.36 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2910.750, dens: 51.816%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2910.750 -> 2907.839
# [INFO] [00:00:00] <main> [SEP] separating at width: 2907.839 and loss: 106 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 518 K, evals/move: 261, moves/s: 1.98 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2907.839, dens: 51.868%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2907.839 -> 2904.931
# [INFO] [00:00:00] <main> [SEP] separating at width: 2904.931 and loss: 107 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 536 K, evals/move: 231, moves/s: 2.32 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2904.931, dens: 51.919%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2904.931 -> 2902.027
# [INFO] [00:00:00] <main> [SEP] separating at width: 2902.027 and loss: 109 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 430 K, evals/move: 289, moves/s: 1.48 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2902.027, dens: 51.971%)
# [INFO] [00:00:00] <main> [EXPL] shrinking strip by 0.1%: 2902.027 -> 2899.125
# [INFO] [00:00:00] <main> [SEP] separating at width: 2899.125 and loss: 60.2 K
# [INFO] [00:00:00] <main> [SEP] [s:0,i:0] (S)  min_l: 0
# [INFO] [00:00:00] <main> [SEP] finished, evals/s: 496 K, evals/move: 270, moves/s: 1.83 K, iter/s: 0, #workers: 3, total 0.0s
# [INFO] [00:00:00] <main> [EXPL] feasible solution found! (width: 2899.125, dens: 52.023%)
# ...
# [INFO] [00:05:25] <main> [SEP] separating at width: 2282.549 and loss: 50.3 K
# [INFO] [00:05:25] <main> [SEP] [s:0,i:0] (*) min_l: 50.3 K
# [INFO] [00:05:31] <main> [SEP] finished, evals/s: 481 K, evals/move: 263, moves/s: 1.82 K, iter/s: 95.9, #workers: 3, total 6.2s
# [INFO] [00:05:31] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 50.)
# [INFO] [00:05:31] <main> [EXPL] starting solution 0/30 selected from solution pool (l: 50.3 K) to disrupt
# [INFO] [00:05:31] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:05:31] <main> [SEP] separating at width: 2282.549 and loss: 50.3 K
# [INFO] [00:05:38] <main> [SEP] finished, evals/s: 484 K, evals/move: 263, moves/s: 1.83 K, iter/s: 87.3, #workers: 3, total 6.8s
# [INFO] [00:05:38] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 50.)
# [INFO] [00:05:38] <main> [EXPL] starting solution 4/31 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:05:38] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:05:38] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:05:38] <main> [SEP] [s:0,i:0] (*) min_l: 56.2 K
# [INFO] [00:05:44] <main> [SEP] finished, evals/s: 477 K, evals/move: 264, moves/s: 1.80 K, iter/s: 101, #workers: 3, total 5.9s
# [INFO] [00:05:44] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:05:44] <main> [EXPL] starting solution 3/32 selected from solution pool (l: 55.8 K) to disrupt
# [INFO] [00:05:44] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:05:44] <main> [SEP] separating at width: 2282.549 and loss: 55.8 K
# [INFO] [00:05:44] <main> [SEP] [s:0,i:0] (*) min_l: 55.8 K
# [INFO] [00:05:46] <main> [SEP] [s:1,i:202] (*) min_l: 55.8 K
# [INFO] [00:05:50] <main> [SEP] finished, evals/s: 481 K, evals/move: 263, moves/s: 1.82 K, iter/s: 103, #workers: 3, total 5.8s
# [INFO] [00:05:50] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 55.)
# [INFO] [00:05:50] <main> [EXPL] starting solution 6/33 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:05:50] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:05:50] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:05:56] <main> [SEP] finished, evals/s: 474 K, evals/move: 263, moves/s: 1.79 K, iter/s: 100, #workers: 3, total 5.9s
# [INFO] [00:05:56] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:05:56] <main> [EXPL] starting solution 5/34 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:05:56] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:05:56] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:05:56] <main> [SEP] [s:0,i:0] (*) min_l: 56.2 K
# [INFO] [00:06:02] <main> [SEP] finished, evals/s: 480 K, evals/move: 263, moves/s: 1.82 K, iter/s: 90.1, #workers: 3, total 6.6s
# [INFO] [00:06:02] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:06:02] <main> [EXPL] starting solution 3/35 selected from solution pool (l: 55.8 K) to disrupt
# [INFO] [00:06:02] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:06:02] <main> [SEP] separating at width: 2282.549 and loss: 55.8 K
# [INFO] [00:06:02] <main> [SEP] [s:0,i:0] (*) min_l: 55.8 K
# [INFO] [00:06:04] <main> [SEP] [s:1,i:201] (*) min_l: 55.8 K
# [INFO] [00:06:08] <main> [SEP] finished, evals/s: 477 K, evals/move: 264, moves/s: 1.80 K, iter/s: 98.6, #workers: 3, total 6.1s
# [INFO] [00:06:08] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 55.)
# [INFO] [00:06:08] <main> [EXPL] starting solution 8/36 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:06:08] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:06:08] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:06:08] <main> [SEP] [s:0,i:2] (*) min_l: 56.0 K
# [INFO] [00:06:10] <main> [SEP] [s:1,i:202] (*) min_l: 56.0 K
# [INFO] [00:06:15] <main> [SEP] finished, evals/s: 482 K, evals/move: 263, moves/s: 1.82 K, iter/s: 91.4, #workers: 3, total 6.5s
# [INFO] [00:06:15] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:06:15] <main> [EXPL] starting solution 8/37 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:06:15] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:06:15] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:06:21] <main> [SEP] finished, evals/s: 479 K, evals/move: 263, moves/s: 1.82 K, iter/s: 98.7, #workers: 3, total 6.0s
# [INFO] [00:06:21] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:06:21] <main> [EXPL] starting solution 10/38 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:06:21] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:06:21] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:06:23] <main> [SEP] [s:1,i:200] (*) min_l: 56.2 K
# [INFO] [00:06:27] <main> [SEP] finished, evals/s: 480 K, evals/move: 263, moves/s: 1.82 K, iter/s: 98.4, #workers: 3, total 6.1s
# [INFO] [00:06:27] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:06:27] <main> [EXPL] starting solution 7/39 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:06:27] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:06:27] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:06:27] <main> [SEP] [s:0,i:0] (*) min_l: 56.2 K
# [INFO] [00:06:30] <main> [SEP] [s:2,i:418] (*) min_l: 54.9 K
# [INFO] [00:06:33] <main> [SEP] [s:0,i:619] (*) min_l: 53.5 K
# [INFO] [00:06:33] <main> [SEP] [s:0,i:620] (*) min_l: 53.5 K
# [INFO] [00:06:33] <main> [SEP] [s:0,i:625] (*) min_l: 51.8 K
# [INFO] [00:06:41] <main> [SEP] finished, evals/s: 475 K, evals/move: 263, moves/s: 1.80 K, iter/s: 104, #workers: 3, total 13.s
# [INFO] [00:06:41] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 51.)
# [INFO] [00:06:41] <main> [EXPL] starting solution 3/40 selected from solution pool (l: 51.8 K) to disrupt
# [INFO] [00:06:41] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:06:41] <main> [SEP] separating at width: 2282.549 and loss: 51.8 K
# [INFO] [00:06:41] <main> [SEP] [s:0,i:0] (*) min_l: 51.8 K
# [INFO] [00:06:43] <main> [SEP] [s:1,i:201] (*) min_l: 51.7 K
# [INFO] [00:06:43] <main> [SEP] [s:1,i:206] (*) min_l: 51.6 K
# [INFO] [00:06:45] <main> [SEP] [s:2,i:403] (*) min_l: 51.5 K
# [INFO] [00:06:47] <main> [SEP] finished, evals/s: 485 K, evals/move: 263, moves/s: 1.84 K, iter/s: 96.4, #workers: 3, total 6.2s
# [INFO] [00:06:47] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 51.)
# [INFO] [00:06:47] <main> [EXPL] starting solution 16/41 selected from solution pool (l: 56.4 K) to disrupt
# [INFO] [00:06:47] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:06:47] <main> [SEP] separating at width: 2282.549 and loss: 56.4 K
# [INFO] [00:06:53] <main> [SEP] finished, evals/s: 476 K, evals/move: 263, moves/s: 1.80 K, iter/s: 101, #workers: 3, total 5.9s
# [INFO] [00:06:53] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:06:53] <main> [EXPL] starting solution 7/42 selected from solution pool (l: 55.8 K) to disrupt
# [INFO] [00:06:53] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:06:53] <main> [SEP] separating at width: 2282.549 and loss: 55.8 K
# [INFO] [00:06:53] <main> [SEP] [s:0,i:1] (*) min_l: 55.8 K
# [INFO] [00:06:59] <main> [SEP] finished, evals/s: 482 K, evals/move: 262, moves/s: 1.83 K, iter/s: 96.8, #workers: 3, total 6.2s
# [INFO] [00:06:59] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 55.)
# [INFO] [00:06:59] <main> [EXPL] starting solution 25/43 selected from solution pool (l: 56.4 K) to disrupt
# [INFO] [00:06:59] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:06:59] <main> [SEP] separating at width: 2282.549 and loss: 56.4 K
# [INFO] [00:07:06] <main> [SEP] finished, evals/s: 487 K, evals/move: 263, moves/s: 1.84 K, iter/s: 90.2, #workers: 3, total 6.6s
# [INFO] [00:07:06] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:07:06] <main> [EXPL] starting solution 6/44 selected from solution pool (l: 55.8 K) to disrupt
# [INFO] [00:07:06] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:07:06] <main> [SEP] separating at width: 2282.549 and loss: 55.8 K
# [INFO] [00:07:06] <main> [SEP] [s:0,i:0] (*) min_l: 55.8 K
# [INFO] [00:07:08] <main> [SEP] [s:1,i:206] (*) min_l: 55.7 K
# [INFO] [00:07:10] <main> [SEP] [s:2,i:402] (*) min_l: 55.7 K
# [INFO] [00:07:12] <main> [SEP] finished, evals/s: 479 K, evals/move: 263, moves/s: 1.81 K, iter/s: 96.0, #workers: 3, total 6.2s
# [INFO] [00:07:12] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 55.)
# [INFO] [00:07:12] <main> [EXPL] starting solution 12/45 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:07:12] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:07:12] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:07:12] <main> [SEP] [s:0,i:0] (*) min_l: 56.2 K
# [INFO] [00:07:19] <main> [SEP] finished, evals/s: 475 K, evals/move: 264, moves/s: 1.80 K, iter/s: 92.8, #workers: 3, total 6.4s
# [INFO] [00:07:19] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:07:19] <main> [EXPL] starting solution 12/46 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:07:19] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:07:19] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:07:19] <main> [SEP] [s:0,i:0] (*) min_l: 56.2 K
# [INFO] [00:07:22] <main> [SEP] [s:2,i:402] (*) min_l: 56.2 K
# [INFO] [00:07:24] <main> [SEP] finished, evals/s: 470 K, evals/move: 262, moves/s: 1.79 K, iter/s: 102, #workers: 3, total 5.8s
# [INFO] [00:07:24] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:07:24] <main> [EXPL] starting solution 1/47 selected from solution pool (l: 50.3 K) to disrupt
# [INFO] [00:07:24] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:07:24] <main> [SEP] separating at width: 2282.549 and loss: 50.3 K
# [INFO] [00:07:30] <main> [SEP] finished, evals/s: 477 K, evals/move: 263, moves/s: 1.80 K, iter/s: 103, #workers: 3, total 5.8s
# [INFO] [00:07:30] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 50.)
# [INFO] [00:07:30] <main> [EXPL] starting solution 8/48 selected from solution pool (l: 55.8 K) to disrupt
# [INFO] [00:07:30] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:07:30] <main> [SEP] separating at width: 2282.549 and loss: 55.8 K
# [INFO] [00:07:30] <main> [SEP] [s:0,i:0] (*) min_l: 55.8 K
# [INFO] [00:07:32] <main> [SEP] [s:1,i:201] (*) min_l: 55.8 K
# [INFO] [00:07:36] <main> [SEP] finished, evals/s: 477 K, evals/move: 263, moves/s: 1.81 K, iter/s: 97.1, #workers: 3, total 6.1s
# [INFO] [00:07:36] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 55.)
# [INFO] [00:07:36] <main> [EXPL] starting solution 19/49 selected from solution pool (l: 56.2 K) to disrupt
# [INFO] [00:07:36] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:07:36] <main> [SEP] separating at width: 2282.549 and loss: 56.2 K
# [INFO] [00:07:36] <main> [SEP] [s:0,i:0] (*) min_l: 56.2 K
# [INFO] [00:07:42] <main> [SEP] finished, evals/s: 477 K, evals/move: 263, moves/s: 1.81 K, iter/s: 102, #workers: 3, total 5.8s
# [INFO] [00:07:42] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 56.)
# [INFO] [00:07:42] <main> [EXPL] starting solution 4/50 selected from solution pool (l: 51.5 K) to disrupt
# [INFO] [00:07:42] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:07:42] <main> [SEP] separating at width: 2282.549 and loss: 51.5 K
# [INFO] [00:07:42] <main> [SEP] [s:0,i:0] (*) min_l: 51.5 K
# [INFO] [00:07:45] <main> [SEP] [s:1,i:201] (*) min_l: 51.5 K
# [INFO] [00:07:46] <main> [SEP] [s:2,i:402] (*) min_l: 51.5 K
# [INFO] [00:07:49] <main> [SEP] finished, evals/s: 481 K, evals/move: 265, moves/s: 1.81 K, iter/s: 96.3, #workers: 3, total 6.2s
# [INFO] [00:07:49] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 51.)
# [INFO] [00:07:49] <main> [EXPL] starting solution 5/51 selected from solution pool (l: 51.5 K) to disrupt
# [INFO] [00:07:49] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:07:49] <main> [SEP] separating at width: 2282.549 and loss: 51.5 K
# [INFO] [00:07:49] <main> [SEP] [s:0,i:0] (*) min_l: 51.5 K
# [INFO] [00:07:55] <main> [SEP] finished, evals/s: 483 K, evals/move: 263, moves/s: 1.83 K, iter/s: 90.3, #workers: 3, total 6.6s
# [INFO] [00:07:55] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 51.)
# [INFO] [00:07:55] <main> [EXPL] starting solution 5/52 selected from solution pool (l: 51.5 K) to disrupt
# [INFO] [00:07:55] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:07:55] <main> [SEP] separating at width: 2282.549 and loss: 51.5 K
# [INFO] [00:07:55] <main> [SEP] [s:0,i:0] (*) min_l: 51.5 K
# [INFO] [00:08:00] <main> [SEP] finished, evals/s: 477 K, evals/move: 264, moves/s: 1.80 K, iter/s: 123, #workers: 3, total 4.8s
# [INFO] [00:08:00] <main> [EXPL] unable to reach feasibility (width: 2282.549, dens: 66.076%, min loss: 51.)
# [INFO] [00:08:00] <main> [EXPL] starting solution 7/53 selected from solution pool (l: 51.5 K) to disrupt
# [INFO] [00:08:00] <main> [EXPL] disrupting by swapping two large items (id: 0 <-> 0)
# [INFO] [00:08:00] <main> [EXPL] finished, best feasible solution: width: 2284.833 (66.010%)
# [INFO] [00:08:00] <main> [CMPR] success at 0.050% (2283.691 | 66.043%)
# [INFO] [00:08:07] <main> [CMPR] failed at 0.050%
# [INFO] [00:08:11] <main> [CMPR] success at 0.047% (2282.613 | 66.074%)
# [INFO] [00:08:17] <main> [CMPR] failed at 0.046%
# [INFO] [00:08:27] <main> [CMPR] failed at 0.043%
# [INFO] [00:08:37] <main> [CMPR] failed at 0.039%
# [INFO] [00:08:43] <main> [CMPR] failed at 0.035%
# [INFO] [00:08:50] <main> [CMPR] failed at 0.032%
# [INFO] [00:08:50] <main> [CMPR] success at 0.030% (2281.937 | 66.094%)
# [INFO] [00:09:02] <main> [CMPR] failed at 0.030%
# [INFO] [00:09:08] <main> [CMPR] failed at 0.025%
# [INFO] [00:09:15] <main> [CMPR] failed at 0.022%
# [INFO] [00:09:24] <main> [CMPR] failed at 0.019%
# [INFO] [00:09:33] <main> [CMPR] failed at 0.016%
# [INFO] [00:09:39] <main> [CMPR] failed at 0.012%
# [INFO] [00:09:45] <main> [CMPR] failed at 0.009%
# [INFO] [00:09:48] <main> [CMPR] success at 0.007% (2281.775 | 66.099%)
# [INFO] [00:09:49] <main> [CMPR] success at 0.006% (2281.638 | 66.103%)
# [INFO] [00:09:49] <main> [CMPR] success at 0.006% (2281.508 | 66.106%)
# [INFO] [00:09:49] <main> [CMPR] success at 0.006% (2281.378 | 66.110%)
# [INFO] [00:09:53] <main> [CMPR] success at 0.006% (2281.248 | 66.114%)
# [INFO] [00:09:53] <main> [CMPR] success at 0.004% (2281.160 | 66.117%)
# [INFO] [00:09:59] <main> [CMPR] failed at 0.004%
# [INFO] [00:10:00] <main> [CMPR] failed at 0.001%
# [INFO] [00:10:00] <main> [CMPR] finished, compressed from 66.010% to 66.117% (+0.106%)
# [INFO] [00:10:00] <main> [IO] svg exported to file:///kaggle/working/sparrow/output/final_n14_h2280.svg
# [INFO] [00:10:00] <main> [IO] json exported to file:///kaggle/working/sparrow/output/final_n14_h2280.json

# %%
from IPython.display import SVG, display
display(SVG('/kaggle/working/sparrow/output/final_n14_h2280.svg'))

# %%
# !cp /kaggle/input/santa-submission/submission.csv submission.csv

# %%
"""Merge sparrow solution into submission.csv if score is better."""

import json
import sys
import math
from pathlib import Path

SCALE = 1000.0

# Tree polygon vertices
TREE_VERTS = [
    (0.0, 0.8), (0.125, 0.5), (0.0625, 0.5), (0.2, 0.25), (0.1, 0.25),
    (0.35, 0.0), (0.075, 0.0), (0.075, -0.2), (-0.075, -0.2), (-0.075, 0.0),
    (-0.35, 0.0), (-0.1, 0.25), (-0.2, 0.25), (-0.0625, 0.5), (-0.125, 0.5)
]

def transform_point(x, y, tx, ty, deg):
    rad = math.radians(deg)
    c, s = math.cos(rad), math.sin(rad)
    rx = x * c - y * s
    ry = x * s + y * c
    return rx + tx, ry + ty

def calc_score(placements):
    """Calculate score from placements [(x, y, deg), ...]"""
    min_x = min_y = float('inf')
    max_x = max_y = float('-inf')

    for tx, ty, deg in placements:
        for vx, vy in TREE_VERTS:
            px, py = transform_point(vx, vy, tx, ty, deg)
            min_x = min(min_x, px)
            max_x = max(max_x, px)
            min_y = min(min_y, py)
            max_y = max(max_y, py)

    width = max_x - min_x
    height = max_y - min_y
    side = max(width, height)
    return side ** 2 / len(placements)

def load_submission(csv_path):
    """Load submission.csv into dict {id: (x, y, deg)}"""
    data = {}
    with open(csv_path) as f:
        header = f.readline()  # skip header
        for line in f:
            line = line.strip()
            if not line:
                continue
            parts = line.split(',')
            id_ = parts[0]
            x = float(parts[1][1:])  # remove 's' prefix
            y = float(parts[2][1:])
            deg = float(parts[3][1:])
            data[id_] = (x, y, deg)
    return data

def extract_group(data, group):
    """Extract placements for a specific group (e.g., '014')"""
    placements = []
    i = 0
    while f"{group}_{i}" in data:
        placements.append(data[f"{group}_{i}"])
        i += 1
    return placements

def load_sparrow(json_path):
    """Load placements from sparrow JSON output"""
    with open(json_path) as f:
        data = json.load(f)

    sol = data.get('solution', data)
    placements = []

    for item in sol['layout']['placed_items']:
        t = item['transformation']
        x = t['translation'][0] / SCALE
        y = t['translation'][1] / SCALE
        rot = t['rotation']
        placements.append((x, y, rot))

    return placements

def merge(submission_path, sparrow_json, group="014", output_path=None):
    """Merge sparrow solution if better than existing."""

    # Load existing submission
    data = load_submission(submission_path)

    # Get existing group score
    old_placements = extract_group(data, group)
    if not old_placements:
        print(f"Error: Group {group} not found in {submission_path}")
        return False

    old_score = calc_score(old_placements)
    print(f"Existing score for {group}: {old_score:.6f}")

    # Get new sparrow score
    new_placements = load_sparrow(sparrow_json)
    new_score = calc_score(new_placements)
    print(f"New sparrow score:        {new_score:.6f}")

    if new_score >= old_score:
        print(f"\nNo improvement. Keeping existing solution.")
        return False

    improvement = old_score - new_score
    print(f"\nImprovement: {improvement:.6f} ({improvement/old_score*100:.2f}%)")

    # Merge: replace group entries
    for i, (x, y, deg) in enumerate(new_placements):
        data[f"{group}_{i}"] = (x, y, deg)

    # Write output
    out_path = output_path or submission_path

    # Sort keys properly (by group, then index)
    def sort_key(k):
        parts = k.split('_')
        return (parts[0], int(parts[1]))

    sorted_keys = sorted(data.keys(), key=sort_key)

    with open(out_path, 'w') as f:
        f.write("id,x,y,deg\n")
        for k in sorted_keys:
            x, y, deg = data[k]
            f.write(f"{k},s{x:.17f},s{y:.17f},s{deg:.17f}\n")

    print(f"Merged! Saved to {out_path}")

merge('submission.csv', 'sparrow/output/final_n14_h2280.json', "014")
# Out:
# Existing score for 014: 0.380398
# New sparrow score:        0.371689
#
# Improvement: 0.008709 (2.29%)
# Merged! Saved to submission.csv
# True

# %%
# !cp -r /kaggle/working/sparrow/output output
# !rm -r /kaggle/working/sparrow
