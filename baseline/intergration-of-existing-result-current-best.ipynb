# %% [markdown]
# ## 🎯 Here’s the Cool Part
#
# Since each of the 1‑200 **Christmas trees** in this competition is independent 🎄, we’ve brought together **ALL** available open‑source solutions 🤝 — merging them into **one super‑strong final answer**!
#
# The code is designed for **flexibility** 🧩:
# - 🔄 **Update results** anytime
# - 📓 **Drop in new open‑source notebooks**
# - 🚀 **Push toward the top score** with your own improvements

# %% [markdown]
# 📝 How to Use & Update
# To get the best results, don’t forget to:
#
# 🔄 Update the public notebooks already added
#
# 📥 Manually add any new open-source notebooks that become available
#
# 🎯 Quick Tip
# Remember to refresh existing notebooks or drop in new ones to keep your solution up to date!
#
# ✨ Stay Updated
# Keep your solution strong by:
#
# 🔄 Updating added notebooks
#
# ➕ Adding new open-source notebooks as they’re released

# %%
#!pip install shapely numba

# %%
import shutil


shutil.copy('/kaggle/input/why-not/submission.csv',  '/kaggle/working/submission1.csv')
shutil.copy('/kaggle/input/santa-submission/submission.csv',  '/kaggle/working/submission2.csv')
shutil.copy('/kaggle/input/santa2025-bbox-optimization/submission.csv',  '/kaggle/working/submission3.csv')
shutil.copy('/kaggle/input/new-year-same-old-bbox/submission.csv',  '/kaggle/working/submission4.csv')
# shutil.copy('/kaggle/input/magic-fast-backprop/submission.csv',  '/kaggle/working/submission5.csv')
shutil.copy('/kaggle/input/fork-of-santa-submission-happy-new-year/submission.csv',  '/kaggle/working/submission6.csv')
shutil.copy('/kaggle/input/a-bit-better-the-best-open-source-result-for-date/submission.csv',  '/kaggle/working/submission7.csv')
shutil.copy('/kaggle/input/k/datafad/new-year-same-old-bbox/submission.csv',  '/kaggle/working/submission8.csv')
shutil.copy('/kaggle/input/sa-on-metamodel-from-2-blocks-88-trees/results.csv',  '/kaggle/working/submission9.csv')
# shutil.copy('/kaggle/input/squeezing-bbox-solution/submission_best.csv',  '/kaggle/working/submission10.csv')

shutil.copy('/kaggle/input/sa-on-metamodel-from-2-blocks-132-trees/submission_best.csv',  '/kaggle/working/submission11.csv')
shutil.copy('/kaggle/input/a-super-simple-improvement-strategy/submission.csv',  '/kaggle/working/submission12.csv')
# shutil.copy('/kaggle/input/magic-fast-backprop/submission.csv',  '/kaggle/working/submission13.csv')
# shutil.copy('/kaggle/input/k/chistyakov/squeezing-bbox-solution/submission_best.csv',  '/kaggle/working/submission14.csv')
shutil.copy('/kaggle/input/simulated-annealing-manual-fun-tree-mover/submission.csv',  '/kaggle/working/submission15.csv')
shutil.copy('/kaggle/input/single-group-optimizer-by-manoj/submission.csv',  '/kaggle/working/submission16.csv')
shutil.copy('/kaggle/input/santa-subs-agg-score-track-visual-diagnostics/submission_bestof.csv',  '/kaggle/working/submission17.csv')
shutil.copy('/kaggle/input/new-simple-fix-rebuild-large-layout-from-corners/submission.csv',  '/kaggle/working/submission18.csv')
shutil.copy('/kaggle/input/santa-s-tree-packing-score/submission.csv',  '/kaggle/working/submission19.csv')
shutil.copy('/kaggle/input/the-boxes-shrunk/submission.csv',  '/kaggle/working/submission20.csv')
shutil.copy('/kaggle/input/manual-tree-shifter-and-checker-sa/submission.csv',  '/kaggle/working/submission21.csv')
shutil.copy('/kaggle/input/eazy-optimizer/submission.csv',  '/kaggle/working/submission22.csv')
shutil.copy('/kaggle/input/bbox3-ensemble-update/submission.csv',  '/kaggle/working/submission23.csv')
shutil.copy('/kaggle/input/fast-simulated-annealing-cpp-version-70-6240/submission.csv',  '/kaggle/working/submission24.csv')
shutil.copy('/kaggle/input/bbox-basic/submission.csv',  '/kaggle/working/submission25.csv')
shutil.copy('/kaggle/input/bbox3-ensemble-update/submission.csv',  '/kaggle/working/submission26.csv')
shutil.copy('/kaggle/input/team-optimization-blend/submission.csv',  '/kaggle/working/submission27.csv')
shutil.copy('/kaggle/input/squeezing-bbox-solution/submission.csv',  '/kaggle/working/submission28.csv')



submission_files = [
        '/kaggle/working/submission1.csv',
        '/kaggle/working/submission2.csv',
        '/kaggle/working/submission3.csv',
        '/kaggle/working/submission4.csv',
        '/kaggle/working/submission5.csv',
        '/kaggle/working/submission6.csv',
        '/kaggle/working/submission7.csv',
        '/kaggle/working/submission8.csv',
        '/kaggle/working/submission9.csv',
        # '/kaggle/working/submission10.csv',
        '/kaggle/working/submission11.csv',
        '/kaggle/working/submission12.csv',
        # '/kaggle/working/submission13.csv',
        # '/kaggle/working/submission14.csv',
        '/kaggle/working/submission15.csv',
        '/kaggle/working/submission16.csv',
        '/kaggle/working/submission17.csv',
        '/kaggle/working/submission18.csv',
        '/kaggle/working/submission19.csv',
        '/kaggle/working/submission20.csv',
        '/kaggle/working/submission21.csv',
        '/kaggle/working/submission22.csv',
        '/kaggle/working/submission23.csv',
        '/kaggle/working/submission24.csv',
        '/kaggle/working/submission25.csv',
        '/kaggle/working/submission26.csv',
        '/kaggle/working/submission27.csv',
        '/kaggle/working/submission28.csv',
    
    
    ]

# %%
import pandas as pd
import numpy as np
from decimal import Decimal, getcontext
from shapely import affinity
from shapely.geometry import Polygon
from shapely.strtree import STRtree

# Set precision for Decimal (25 is good for contest standards)
getcontext().prec = 25
scale_factor = Decimal("1e18")


class ChristmasTree:
    """Represents a single, rotatable Christmas tree of a fixed size."""

    def __init__(self, center_x="0", center_y="0", angle="0"):
        """Initializes the Christmas tree with a specific position and rotation."""
        self.center_x = Decimal(center_x)
        self.center_y = Decimal(center_y)
        self.angle = Decimal(angle)

        trunk_w = Decimal("0.15")
        trunk_h = Decimal("0.2")
        base_w = Decimal("0.7")
        mid_w = Decimal("0.4")
        top_w = Decimal("0.25")
        tip_y = Decimal("0.8")
        tier_1_y = Decimal("0.5")
        tier_2_y = Decimal("0.25")
        base_y = Decimal("0.0")
        trunk_bottom_y = -trunk_h

        # Define the 15 vertices of the tree polygon
        initial_polygon = Polygon(
            [
                (Decimal("0.0") * scale_factor, tip_y * scale_factor),
                (top_w / Decimal("2") * scale_factor, tier_1_y * scale_factor),
                (top_w / Decimal("4") * scale_factor, tier_1_y * scale_factor),
                (mid_w / Decimal("2") * scale_factor, tier_2_y * scale_factor),
                (mid_w / Decimal("4") * scale_factor, tier_2_y * scale_factor),
                (base_w / Decimal("2") * scale_factor, base_y * scale_factor),
                (trunk_w / Decimal("2") * scale_factor, base_y * scale_factor),
                (trunk_w / Decimal("2") * scale_factor, trunk_bottom_y * scale_factor),
                (-(trunk_w / Decimal("2")) * scale_factor, trunk_bottom_y * scale_factor),
                (-(trunk_w / Decimal("2")) * scale_factor, base_y * scale_factor),
                (-(base_w / Decimal("2")) * scale_factor, base_y * scale_factor),
                (-(mid_w / Decimal("4")) * scale_factor, tier_2_y * scale_factor),
                (-(mid_w / Decimal("2")) * scale_factor, tier_2_y * scale_factor),
                (-(top_w / Decimal("4")) * scale_factor, tier_1_y * scale_factor),
                (-(top_w / Decimal("2")) * scale_factor, tier_1_y * scale_factor),
            ]
        )
        
        # Apply rotation and translation to the polygon
        rotated = affinity.rotate(initial_polygon, float(self.angle), origin=(0, 0))
        self.polygon = affinity.translate(
            rotated, 
            xoff=float(self.center_x * scale_factor), 
            yoff=float(self.center_y * scale_factor)
        )


def load_configuration_from_df(n: int, df: pd.DataFrame) -> list[ChristmasTree]:
    """
    Loads all trees for a given N from the submission DataFrame.
    """
    group_data = df[df["id"].str.startswith(f"{n:03d}_")]
    trees = []
    for _, row in group_data.iterrows():
        # Remove 's' prefix and convert to string for Decimal constructor
        x = str(row["x"])[1:]
        y = str(row["y"])[1:]
        deg = str(row["deg"])[1:]
        
        # Ensure values are present before passing to ChristmasTree constructor
        if x and y and deg:
            trees.append(ChristmasTree(x, y, deg))
        else:
             # Handle cases where configuration might be incomplete/missing
             pass 
             
    return trees


def get_score(trees: list[ChristmasTree], n: int) -> float:
    """
    Calculates the score (S^2 / N) for a given configuration of trees.
    S is the side length of the minimum bounding square.
    """
    if not trees:
        return 0.0

    # Collect all exterior points from all tree polygons, scale them back down
    xys = np.concatenate([np.asarray(t.polygon.exterior.xy).T / float(scale_factor) for t in trees])
    
    min_x, min_y = xys.min(axis=0)
    max_x, max_y = xys.max(axis=0)
    
    side_length = max(max_x - min_x, max_y - min_y)
    
    # Score is S^2 / N
    score = side_length**2 / n
    return score

def has_overlap(trees: list[ChristmasTree]) -> bool:
    """Check if any two ChristmasTree polygons overlap."""
    if len(trees) <= 1:
        return False

    polygons = [t.polygon for t in trees]
    # Use STRtree for efficient proximity queries (optimizes checking pairs)
    tree_index = STRtree(polygons)

    for i, poly in enumerate(polygons):
        # Query for polygons whose bounding boxes overlap with poly
        # This returns the indices of potential overlaps
        indices = tree_index.query(poly)
        
        for idx in indices:
            # Skip checking the polygon against itself
            if idx == i:
                continue
                
            # Perform the precise intersection check
            if poly.intersects(polygons[idx]) and not poly.touches(polygons[idx]):
                # Overlap found!
                return True
    return False

# ----------------------------------------------------------------------

def score_and_validate_submission(file_path: str, max_n: int = 200) -> dict:
    """
    Reads a submission CSV, calculates the total score, and checks for overlaps 
    in all configurations (N=1 up to max_n).
    """
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return {"status": "FAILED", "error": "File Not Found"}
    except Exception as e:
        print(f"Error reading CSV: {e}")
        return {"status": "FAILED", "error": f"CSV Read Error: {e}"}

    total_score = 0.0
    failed_overlap_n = []
    
    print(f"--- Scoring and Validation: {file_path} (N=1 to {max_n}) ---")

    for n in range(1, max_n + 1):
        trees = load_configuration_from_df(n, df)
        
        # Only process if there are trees for this N in the file
        if trees:
            current_score = get_score(trees, n)
            total_score += current_score

            if has_overlap(trees):
                failed_overlap_n.append(n)
                print(f"  ❌ N={n:03d}: OVERLAP DETECTED! (Score contribution: {current_score:.6f})")
            else:
                # Optionally print success for each N
                # print(f"  ✅ N={n:03d}: OK (Score contribution: {current_score:.6f})")
                pass
        
    print("\n--- Summary ---")
    if failed_overlap_n:
        print(f"❌ **Validation FAILED**: Overlaps found in N: {failed_overlap_n}")
        status = "FAILED (Overlaps)"
    else:
        print("✅ **Validation SUCCESSFUL**: No overlaps detected.")
        status = "SUCCESS"
        
    print(f"**Total Submission Score (Σ S²/N): {total_score:.6f}**")
    
    return {
        "status": status,
        "total_score": total_score,
        "failed_overlap_n": failed_overlap_n
    }

# %%
from pathlib import Path

def merge_best_submissions(file_paths: list[str], output_path: str, max_n: int = 200) -> dict:
    """
    Merges multiple submission files by selecting the best (lowest score) configuration for each N.
    
    Args:
        file_paths: List of paths to submission CSV files
        output_path: Path to save the merged best submission
        max_n: Maximum N value to process
    
    Returns:
        Dictionary with merge statistics and validation results
    """
    print(f"--- Merging {len(file_paths)} submission files ---")
    
    # Load all dataframes
    dfs = []
    for fp in file_paths:
        try:
            df = pd.read_csv(fp)
            dfs.append((fp, df))
            print(f"✓ Loaded: {fp} ({len(df)} rows)")
        except Exception as e:
            print(f"✗ Failed to load {fp}: {e}")
    
    if not dfs:
        return {"status": "FAILED", "error": "No valid files loaded"}
    
    # Store best configurations for each N
    best_configs = []
    selection_stats = {}
    
    for n in range(1, max_n + 1):
        best_score = float('inf')
        best_trees_data = None
        best_source = None
        
        # Compare configurations from all files for this N
        for file_path, df in dfs:
            trees = load_configuration_from_df(n, df)
            
            if trees:
                score = get_score(trees, n)
                
                # Check if this is the best score so far
                if score < best_score:
                    best_score = score
                    # Extract the rows for this N from the dataframe
                    best_trees_data = df[df["id"].str.startswith(f"{n:03d}_")].copy()
                    best_source = Path(file_path).name
        
        # Add the best configuration to the result
        if best_trees_data is not None:
            best_configs.append(best_trees_data)
            selection_stats[n] = {
                "score": best_score,
                "source": best_source
            }
            print(f"N={n:03d}: Best score={best_score:.6f} from {best_source}")
    
    # Combine all best configurations
    if not best_configs:
        return {"status": "FAILED", "error": "No valid configurations found"}
    
    merged_df = pd.concat(best_configs, ignore_index=True)
    
    # Save merged result
    merged_df.to_csv(output_path, index=False)
    print(f"\n✓ Merged submission saved to: {output_path}")
    
    # Validate the merged result
    print("\n--- Validating Merged Submission ---")
    validation_result = score_and_validate_submission(output_path, max_n=max_n)
    
    # Add selection statistics
    source_counts = {}
    for stats in selection_stats.values():
        source = stats["source"]
        source_counts[source] = source_counts.get(source, 0) + 1
    
    print("\n--- Source File Usage ---")
    for source, count in sorted(source_counts.items(), key=lambda x: -x[1]):
        print(f"  {source}: {count} configurations ({count/max_n*100:.1f}%)")
    
    return {
        "status": validation_result["status"],
        "total_score": validation_result["total_score"],
        "failed_overlap_n": validation_result.get("failed_overlap_n", []),
        "merged_file": output_path,
        "source_counts": source_counts,
        "selection_stats": selection_stats
    }


# Example usage
if __name__ == "__main__":
    # List your submission files here
    
    output_file = '/kaggle/working/submission.csv'
    
    result = merge_best_submissions(
        file_paths=submission_files,
        output_path=output_file,
        max_n=200
    )
    
    print("\n=== Final Result ===")
    print(result)
# Out:
# --- Merging 25 submission files ---
# ✓ Loaded: /kaggle/working/submission1.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission2.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission3.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission4.csv (20100 rows)
# ✗ Failed to load /kaggle/working/submission5.csv: [Errno 2] No such file or directory: '/kaggle/working/submission5.csv'
# ✓ Loaded: /kaggle/working/submission6.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission7.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission8.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission9.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission11.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission12.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission15.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission16.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission17.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission18.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission19.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission20.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission21.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission22.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission23.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission24.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission25.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission26.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission27.csv (20100 rows)
# ✓ Loaded: /kaggle/working/submission28.csv (20100 rows)
# N=001: Best score=0.661250 from submission7.csv
# N=002: Best score=0.450779 from submission1.csv
# N=003: Best score=0.434745 from submission1.csv
# N=004: Best score=0.416545 from submission1.csv
# N=005: Best score=0.416850 from submission1.csv
# N=006: Best score=0.399610 from submission1.csv
# N=007: Best score=0.399897 from submission1.csv
# N=008: Best score=0.385407 from submission1.csv
# N=009: Best score=0.385156 from submission22.csv
# N=010: Best score=0.376630 from submission1.csv
# N=011: Best score=0.374924 from submission1.csv
# N=012: Best score=0.372724 from submission22.csv
# N=013: Best score=0.372281 from submission22.csv
# N=014: Best score=0.369543 from submission1.csv
# N=015: Best score=0.376865 from submission22.csv
# N=016: Best score=0.374128 from submission1.csv
# N=017: Best score=0.370040 from submission1.csv
# N=018: Best score=0.368771 from submission1.csv
# N=019: Best score=0.368615 from submission1.csv
# N=020: Best score=0.375695 from submission22.csv
# N=021: Best score=0.374869 from submission22.csv
# N=022: Best score=0.374345 from submission22.csv
# N=023: Best score=0.368750 from submission1.csv
# N=024: Best score=0.365506 from submission1.csv
# N=025: Best score=0.372013 from submission22.csv
# N=026: Best score=0.373997 from submission1.csv
# N=027: Best score=0.362719 from submission1.csv
# N=028: Best score=0.366105 from submission1.csv
# N=029: Best score=0.366722 from submission22.csv
# N=030: Best score=0.360883 from submission1.csv
# N=031: Best score=0.370329 from submission1.csv
# N=032: Best score=0.365417 from submission1.csv
# N=033: Best score=0.369347 from submission22.csv
# N=034: Best score=0.368178 from submission22.csv
# N=035: Best score=0.366855 from submission22.csv
# N=036: Best score=0.358051 from submission22.csv
# N=037: Best score=0.369465 from submission22.csv
# N=038: Best score=0.364563 from submission22.csv
# N=039: Best score=0.360943 from submission22.csv
# N=040: Best score=0.362148 from submission1.csv
# N=041: Best score=0.367831 from submission1.csv
# N=042: Best score=0.366839 from submission1.csv
# N=043: Best score=0.367070 from submission1.csv
# N=044: Best score=0.366271 from submission1.csv
# N=045: Best score=0.363397 from submission1.csv
# N=046: Best score=0.364452 from submission1.csv
# N=047: Best score=0.356898 from submission22.csv
# N=048: Best score=0.354495 from submission22.csv
# N=049: Best score=0.363430 from submission1.csv
# N=050: Best score=0.360753 from submission1.csv
# N=051: Best score=0.364993 from submission22.csv
# N=052: Best score=0.360722 from submission22.csv
# N=053: Best score=0.361855 from submission1.csv
# N=054: Best score=0.356305 from submission22.csv
# N=055: Best score=0.355023 from submission1.csv
# N=056: Best score=0.352278 from submission22.csv
# N=057: Best score=0.353176 from submission22.csv
# N=058: Best score=0.362374 from submission28.csv
# N=059: Best score=0.359853 from submission22.csv
# N=060: Best score=0.357258 from submission1.csv
# N=061: Best score=0.357297 from submission22.csv
# N=062: Best score=0.353580 from submission22.csv
# N=063: Best score=0.352825 from submission23.csv
# N=064: Best score=0.348634 from submission22.csv
# N=065: Best score=0.363793 from submission1.csv
# N=066: Best score=0.358882 from submission1.csv
# N=067: Best score=0.353854 from submission1.csv
# N=068: Best score=0.353620 from submission22.csv
# N=069: Best score=0.354420 from submission22.csv
# N=070: Best score=0.349513 from submission22.csv
# N=071: Best score=0.352232 from submission1.csv
# N=072: Best score=0.348559 from submission1.csv
# N=073: Best score=0.353191 from submission1.csv
# N=074: Best score=0.352206 from submission22.csv
# N=075: Best score=0.352793 from submission22.csv
# N=076: Best score=0.349687 from submission22.csv
# N=077: Best score=0.348684 from submission22.csv
# N=078: Best score=0.351300 from submission22.csv
# N=079: Best score=0.348564 from submission1.csv
# N=080: Best score=0.344879 from submission22.csv
# N=081: Best score=0.355114 from submission22.csv
# N=082: Best score=0.351450 from submission1.csv
# N=083: Best score=0.352358 from submission1.csv
# N=084: Best score=0.350726 from submission1.csv
# N=085: Best score=0.350715 from submission22.csv
# N=086: Best score=0.350088 from submission1.csv
# N=087: Best score=0.353647 from submission22.csv
# N=088: Best score=0.350574 from submission22.csv
# N=089: Best score=0.346693 from submission22.csv
# N=090: Best score=0.343049 from submission22.csv
# N=091: Best score=0.344434 from submission22.csv
# N=092: Best score=0.348310 from submission22.csv
# N=093: Best score=0.346466 from submission22.csv
# N=094: Best score=0.347976 from submission22.csv
# N=095: Best score=0.347732 from submission1.csv
# N=096: Best score=0.346397 from submission22.csv
# N=097: Best score=0.347839 from submission1.csv
# N=098: Best score=0.348826 from submission22.csv
# N=099: Best score=0.345541 from submission1.csv
# N=100: Best score=0.343402 from submission22.csv
# N=101: Best score=0.348727 from submission22.csv
# N=102: Best score=0.347140 from submission22.csv
# N=103: Best score=0.344118 from submission1.csv
# N=104: Best score=0.340810 from submission2.csv
# N=105: Best score=0.342872 from submission1.csv
# N=106: Best score=0.341363 from submission1.csv
# N=107: Best score=0.346077 from submission1.csv
# N=108: Best score=0.343557 from submission22.csv
# N=109: Best score=0.340541 from submission22.csv
# N=110: Best score=0.337603 from submission1.csv
# N=111: Best score=0.343919 from submission1.csv
# N=112: Best score=0.346450 from submission1.csv
# N=113: Best score=0.347797 from submission22.csv
# N=114: Best score=0.345620 from submission22.csv
# N=115: Best score=0.343330 from submission22.csv
# N=116: Best score=0.343513 from submission22.csv
# N=117: Best score=0.341955 from submission2.csv
# N=118: Best score=0.339840 from submission1.csv
# N=119: Best score=0.339077 from submission1.csv
# N=120: Best score=0.337683 from submission1.csv
# N=121: Best score=0.351324 from submission1.csv
# N=122: Best score=0.350173 from submission1.csv
# N=123: Best score=0.347466 from submission22.csv
# N=124: Best score=0.346839 from submission1.csv
# N=125: Best score=0.345548 from submission22.csv
# N=126: Best score=0.344131 from submission22.csv
# N=127: Best score=0.341912 from submission1.csv
# N=128: Best score=0.340700 from submission22.csv
# N=129: Best score=0.341332 from submission22.csv
# N=130: Best score=0.338794 from submission1.csv
# N=131: Best score=0.336252 from submission22.csv
# N=132: Best score=0.333799 from submission1.csv
# N=133: Best score=0.340346 from submission1.csv
# N=134: Best score=0.346472 from submission1.csv
# N=135: Best score=0.347346 from submission1.csv
# N=136: Best score=0.344347 from submission22.csv
# N=137: Best score=0.342808 from submission1.csv
# N=138: Best score=0.341028 from submission2.csv
# N=139: Best score=0.340978 from submission1.csv
# N=140: Best score=0.340098 from submission1.csv
# N=141: Best score=0.343470 from submission22.csv
# N=142: Best score=0.341146 from submission22.csv
# N=143: Best score=0.341044 from submission1.csv
# N=144: Best score=0.339703 from submission22.csv
# N=145: Best score=0.342839 from submission22.csv
# N=146: Best score=0.343436 from submission22.csv
# N=147: Best score=0.341754 from submission1.csv
# N=148: Best score=0.339821 from submission1.csv
# N=149: Best score=0.337923 from submission22.csv
# N=150: Best score=0.337064 from submission1.csv
# N=151: Best score=0.340256 from submission22.csv
# N=152: Best score=0.338483 from submission1.csv
# N=153: Best score=0.336267 from submission22.csv
# N=154: Best score=0.334155 from submission22.csv
# N=155: Best score=0.332069 from submission22.csv
# N=156: Best score=0.329985 from submission1.csv
# N=157: Best score=0.340200 from submission22.csv
# N=158: Best score=0.341273 from submission1.csv
# N=159: Best score=0.340876 from submission1.csv
# N=160: Best score=0.339400 from submission22.csv
# N=161: Best score=0.338630 from submission1.csv
# N=162: Best score=0.337022 from submission1.csv
# N=163: Best score=0.337514 from submission1.csv
# N=164: Best score=0.337328 from submission1.csv
# N=165: Best score=0.335569 from submission1.csv
# N=166: Best score=0.334819 from submission22.csv
# N=167: Best score=0.332835 from submission1.csv
# N=168: Best score=0.332475 from submission22.csv
# N=169: Best score=0.342500 from submission22.csv
# N=170: Best score=0.341484 from submission1.csv
# N=171: Best score=0.341218 from submission22.csv
# N=172: Best score=0.340424 from submission1.csv
# N=173: Best score=0.339392 from submission22.csv
# N=174: Best score=0.339028 from submission22.csv
# N=175: Best score=0.338682 from submission22.csv
# N=176: Best score=0.338149 from submission1.csv
# N=177: Best score=0.336239 from submission1.csv
# N=178: Best score=0.334350 from submission22.csv
# N=179: Best score=0.332595 from submission1.csv
# N=180: Best score=0.331000 from submission1.csv
# N=181: Best score=0.329945 from submission22.csv
# N=182: Best score=0.329988 from submission22.csv
# N=183: Best score=0.339491 from submission1.csv
# N=184: Best score=0.339411 from submission22.csv
# N=185: Best score=0.338562 from submission1.csv
# N=186: Best score=0.340981 from submission1.csv
# N=187: Best score=0.340234 from submission1.csv
# N=188: Best score=0.339480 from submission22.csv
# N=189: Best score=0.338821 from submission1.csv
# N=190: Best score=0.338231 from submission2.csv
# N=191: Best score=0.336756 from submission22.csv
# N=192: Best score=0.335074 from submission22.csv
# N=193: Best score=0.333339 from submission22.csv
# N=194: Best score=0.332999 from submission22.csv
# N=195: Best score=0.332576 from submission22.csv
# N=196: Best score=0.333261 from submission1.csv
# N=197: Best score=0.335868 from submission22.csv
# N=198: Best score=0.337314 from submission22.csv
# N=199: Best score=0.338269 from submission1.csv
# N=200: Best score=0.337548 from submission1.csv
#
# ✓ Merged submission saved to: /kaggle/working/submission.csv
#
# --- Validating Merged Submission ---
# --- Scoring and Validation: /kaggle/working/submission.csv (N=1 to 200) ---
#
# --- Summary ---
# ✅ **Validation SUCCESSFUL**: No overlaps detected.
# **Total Submission Score (Σ S²/N): 70.601032**
#
# --- Source File Usage ---
#   submission1.csv: 98 configurations (49.0%)
#   submission22.csv: 95 configurations (47.5%)
#   submission2.csv: 4 configurations (2.0%)
#   submission7.csv: 1 configurations (0.5%)
#   submission28.csv: 1 configurations (0.5%)
#   submission23.csv: 1 configurations (0.5%)
#
# === Final Result ===
# {'status': 'SUCCESS', 'total_score': np.float64(70.60103223318872), 'failed_overlap_n': [], 'merged_file': '/kaggle/working/submission.csv', 'source_counts': {'submission7.csv': 1, 'submission1.csv': 98, 'submission22.csv': 95, 'submission28.csv': 1, 'submission23.csv': 1, 'submission2.csv': 4}, 'selection_stats': {1: {'score': np.float64(0.6612499999999999), 'source': 'submission7.csv'}, 2: {'score': np.float64(0.45077918286284313), 'source': 'submission1.csv'}, 3: {'score': np.float64(0.43474513897973927), 'source': 'submission1.csv'}, 4: {'score': np.float64(0.4165448485961492), 'source': 'submission1.csv'}, 5: {'score': np.float64(0.4168495908231307), 'source': 'submission1.csv'}, 6: {'score': np.float64(0.3996102867638878), 'source': 'submission1.csv'}, 7: {'score': np.float64(0.3998965505211296), 'source': 'submission1.csv'}, 8: {'score': np.float64(0.3854072516519428), 'source': 'submission1.csv'}, 9: {'score': np.float64(0.38515587918472177), 'source': 'submission22.csv'}, 10: {'score': np.float64(0.3766300406357132), 'source': 'submission1.csv'}, 11: {'score': np.float64(0.3749237190843713), 'source': 'submission1.csv'}, 12: {'score': np.float64(0.37272381070578997), 'source': 'submission22.csv'}, 13: {'score': np.float64(0.3722810298733261), 'source': 'submission22.csv'}, 14: {'score': np.float64(0.36954276920563556), 'source': 'submission1.csv'}, 15: {'score': np.float64(0.37686453583642954), 'source': 'submission22.csv'}, 16: {'score': np.float64(0.3741279942223038), 'source': 'submission1.csv'}, 17: {'score': np.float64(0.3700403001341405), 'source': 'submission1.csv'}, 18: {'score': np.float64(0.36877122977731536), 'source': 'submission1.csv'}, 19: {'score': np.float64(0.3686153320170858), 'source': 'submission1.csv'}, 20: {'score': np.float64(0.3756951859025443), 'source': 'submission22.csv'}, 21: {'score': np.float64(0.37486876760487325), 'source': 'submission22.csv'}, 22: {'score': np.float64(0.3743452663380801), 'source': 'submission22.csv'}, 23: {'score': np.float64(0.3687504229807206), 'source': 'submission1.csv'}, 24: {'score': np.float64(0.3655055886437579), 'source': 'submission1.csv'}, 25: {'score': np.float64(0.3720131439061231), 'source': 'submission22.csv'}, 26: {'score': np.float64(0.3739969552336244), 'source': 'submission1.csv'}, 27: {'score': np.float64(0.3627188742947188), 'source': 'submission1.csv'}, 28: {'score': np.float64(0.36610521261929685), 'source': 'submission1.csv'}, 29: {'score': np.float64(0.36672180671109217), 'source': 'submission22.csv'}, 30: {'score': np.float64(0.3608834425955312), 'source': 'submission1.csv'}, 31: {'score': np.float64(0.37032927462333326), 'source': 'submission1.csv'}, 32: {'score': np.float64(0.36541724933648645), 'source': 'submission1.csv'}, 33: {'score': np.float64(0.3693468539024901), 'source': 'submission22.csv'}, 34: {'score': np.float64(0.3681781234025909), 'source': 'submission22.csv'}, 35: {'score': np.float64(0.3668548660582157), 'source': 'submission22.csv'}, 36: {'score': np.float64(0.3580510127089932), 'source': 'submission22.csv'}, 37: {'score': np.float64(0.3694654683195093), 'source': 'submission22.csv'}, 38: {'score': np.float64(0.36456331854933544), 'source': 'submission22.csv'}, 39: {'score': np.float64(0.36094285695936595), 'source': 'submission22.csv'}, 40: {'score': np.float64(0.36214803161841075), 'source': 'submission1.csv'}, 41: {'score': np.float64(0.36783117312602964), 'source': 'submission1.csv'}, 42: {'score': np.float64(0.3668386120399588), 'source': 'submission1.csv'}, 43: {'score': np.float64(0.3670699405853328), 'source': 'submission1.csv'}, 44: {'score': np.float64(0.36627065987634366), 'source': 'submission1.csv'}, 45: {'score': np.float64(0.363396826439528), 'source': 'submission1.csv'}, 46: {'score': np.float64(0.36445246612508897), 'source': 'submission1.csv'}, 47: {'score': np.float64(0.35689813847872315), 'source': 'submission22.csv'}, 48: {'score': np.float64(0.35449451427876016), 'source': 'submission22.csv'}, 49: {'s ...
